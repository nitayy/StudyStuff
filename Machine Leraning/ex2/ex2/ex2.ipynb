# %%
from sklearn.datasets import load_digits
digits = load_digits()
print(digits.data.shape)

import matplotlib.pyplot as plt 
for i in (range(20)):
    plt.gray()
    plt.matshow(digits.images[i])
    plt.show()
# Out:
# (1797, 64)

# %% [markdown]
# ##### Some lines:

# %%
def get_first_cols(m):
    """
    The function gets a matrix m at size l*l (l must be even!), and returns the first l/2 columns.
    :param m: The matrix m.
    :return: A matrix of first l/2 columns of m.
    """
    l=len(m)
    return m[:,3]
a=[[  0.,   0.,   5.,  13.,   9.,   1.,   0.,   0.],
       [  0.,   0.,  13.,  15.,  10.,  15.,   5.,   0.],
       [  0.,   3.,  15.,   2.,   0.,  11.,   8.,   0.],
       [  0.,   4.,  12.,   0.,   0.,   8.,   8.,   0.],
       [  0.,   5.,   8.,   0.,   0.,   9.,   8.,   0.],
       [  0.,   4.,  11.,   0.,   1.,  12.,   7.,   0.],
       [  0.,   2.,  14.,   5.,  10.,  12.,   0.,   0.],
       [  0.,   0.,   6.,  13.,  10.,   0.,   0.,   0.]]

get_first_cols(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-eb94d79af132> in <module>()
#      16        [  0.,   0.,   6.,  13.,  10.,   0.,   0.,   0.]]
#      17
# ---> 18 get_first_cols(a)
#
# <ipython-input-2-eb94d79af132> in get_first_cols(m)
#       6     """
#       7     l=len(m)
# ----> 8     return m[:,3]
#       9 a=[[  0.,   0.,   5.,  13.,   9.,   1.,   0.,   0.],
#      10        [  0.,   0.,  13.,  15.,  10.,  15.,   5.,   0.],
#
# TypeError: list indices must be integers, not tuple

# %%
def foo():
    return [1,2,3]

a=foo()[1]+5
print(a)
# Out:
# 7

# %%
a=4
b=3
c=[a,b]
for i in c:
    print (i)
# Out:
# 4
# 3
